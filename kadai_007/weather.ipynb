# %%
array = ["月曜日は晴れです", "火曜日は雨です", "水曜日は晴れです", "木曜日は晴れです", "金曜日は曇りです", "土曜日は曇りのち雨です", "日曜日は雷雨です"]
dictionary = {"mon": "晴れ", "tue": "雨", "wed": "晴れ", "thu": "晴れ", "fri": "曇り", "sat": "曇りのち晴れ", "sun": "雷雨"}

print("arrayの結果：" + array[2])
print("dictionaryの結果：" + dictionary["wed"])
# Out:
# arrayの結果：水曜日は晴れです
# dictionaryの結果：晴れ
