# %%
array = ["水","金","地","火","木","土","天","海","冥"]

# for文で出力
for day_week1 in array:
    print(day_week1)

# while文で出力
i = 0
while i != 9:
    print(array[i])
    i = i +1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
